# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.sample(3)
# Out:
#      property_type      society      sector  price  price_per_sqft    area  \
# 848          house  independent    sector 8   0.82         10224.0   802.0
# 1145          flat  zara aavaas  sector 104   0.40          7029.0   569.0
# 2737          flat   paras dews  sector 106   1.13          6406.0  1764.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 848                      Carpet area: 802 (74.51 sq.m.)        4         4
# 1145               Super Built up area 569(52.86 sq.m.)        2         2
# 2737  Super Built up area 1760(163.51 sq.m.)Built Up...        3         4
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 848        0       2.0         NaN       Undefined                  NaN
# 1145       1      14.0         NaN  Relatively New                569.0
# 2737      3+      18.0  North-West  Relatively New               1760.0
#
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))
sns.histplot(x='price',data=df,kde=True,color='orange',stat='density')
plt.title('Distribution of Prices with KDE')
plt.show()

# %%
sns.boxplot(x='price',data=df,color='lightgreen')
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(10)
# Out:
#      property_type                                            society  \
# 821          house  arjun marg/ sector- 26 phase- 1/ golf course road
# 2834         house                                        independent
# 2488         house                                     dlf city plots
# 2211         house                                        independent
# 1686         house                                   suncity township
# 3046         house                             emaar the palm springs
# 2765         house                                        independent
# 2667         house                                 vipul tatvam villa
# 874          house                                     dlf city plots
# 2096         house                             luxury dlf city floors
#
#          sector  price  price_per_sqft     area  \
# 821   sector 26   31.5         35000.0   9000.0
# 2834  sector 43   27.5         24366.0  11286.0
# 2488  sector 26   26.0         57206.0   4545.0
# ...

# %% [markdown]
# - on the basis of price col we can say that there are some genuine outliers but there are some data erros as well

# %% [markdown]
# ### Price_per_sqft

# %%
plt.figure(figsize=(15,5))
sns.histplot(x='price_per_sqft',data=df,stat='density',kde=True,color='orange')
plt.show()

# %%
sns.boxplot(x='price_per_sqft',data=df,color='lightgreen')
plt.show()

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft.loc[outliers_sqft['area'] < 1000, 'area'] = outliers_sqft.loc[outliers_sqft['area'] < 1000, 'area'].apply(lambda x: x * 9)

# %%
outliers_sqft.loc[:, 'price_per_sqft'] = round((outliers_sqft['price'] * 10000000) / outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
plt.figure(figsize=(15,5))
sns.histplot(x='price_per_sqft', data=df, kde=True, stat='density',color='orange')
plt.show()

# %%
sns.boxplot(x='price_per_sqft', data=df, color='orange')
plt.show()

# %% [markdown]
# - Taking properties below 50000 to remove some outliers

# %%
df = df[df['price_per_sqft'] <= 50000]
sns.boxplot(x='price_per_sqft', data=df, color='orange')
plt.show()

# %% [markdown]
# ### Area

# %%
plt.figure(figsize=(15,5))
sns.histplot(x='area', data=df, kde=True, stat='density',color='lightpink')
plt.show()

# %%
sns.boxplot(x='area', data=df, color='orange')
plt.show()

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %% [markdown]
# - Taking area below 100000 to remmove outliers

# %%
df = df[df['area'] < 100000]
plt.figure(figsize=(15,5))
sns.histplot(x='area', data=df, kde=True, stat='density',color='lightpink')
plt.show()

# %%
sns.boxplot(x='area', data=df, color='orange')
plt.show()

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society      sector  price  \
# 818          house                independent   sector 26  18.40
# 48           house  ganpati heights apartment   sector 13   1.25
# 1123          flat                 rof ananda   sector 95   0.38
# 1796          flat                 rof ananda   sector 95   0.38
# 300          house      dlf city plot phase 4   sector 28  13.00
# 2             flat              pyramid elite   sector 86   0.46
# 2356          flat                 rof ananda   sector 95   0.33
# 115           flat      signature the serenas  sohna road   0.28
# 2666         house                independent   sector 25   7.30
# 3649          flat            ramsons kshitij   sector 95   0.24
# 2503          flat                 rof ananda   sector 95   0.21
# 1358         house                independent   sector 57   6.25
# 3195         house                independent   sector 43   5.50
# ...

# %%
# Removing these indexes because there is mismatch between area and rooms count and with other columns, making it incorrect data
df.drop(index=[818, 1796, 1123, 2, 2356, 115, 3649, 2503, 1471], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society      sector  price  \
# 48           house  ganpati heights apartment   sector 13   1.25
# 300          house      dlf city plot phase 4   sector 28  13.00
# 2666         house                independent   sector 25   7.30
# 1358         house                independent   sector 57   6.25
# 3195         house                independent   sector 43   5.50
# 2131          flat                 godrej air   sector 85   2.50
# 3088         house       unitech aspen greens   sector 50   6.95
# 3444          flat                godrej icon  sector 88a   1.75
# 2834         house                independent   sector 43  27.50
# 2342          flat             m3m golfestate   sector 65  13.20
# 747          house                independent  sohna road   5.50
#
#       price_per_sqft     area  \
# 48             151.0  82781.0
# 300           1992.0  65261.0
# 2666          1560.0  46795.0
# 1358          2778.0  22498.0
# ...

# %%
# Manually assigning carpet area as area for the rows

df.loc[48,'area'] = 115*9
df.loc[300,'area'] = 7250
df.loc[2666,'area'] = 5800
df.loc[1358,'area'] = 2660
df.loc[3195,'area'] = 2850
df.loc[2131,'area'] = 1812
df.loc[3088,'area'] = 2160
df.loc[3444,'area'] = 1175

# %% [markdown]
# - Checking distribution again after removing outliers

# %%
plt.figure(figsize=(15,5))
sns.histplot(x='area', data=df, kde=True, stat='density',color='orange')
plt.show()

# %%
sns.boxplot(x='area', data=df, color='lightgreen')
plt.show()

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      1950.357005
# std       1215.707897
# min        145.000000
# 25%       1260.000000
# 50%       1747.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# ### Bedroom

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='bedRoom', data=df, kde=True, stat='density',color='orange')
plt.show()

# %%
sns.boxplot(x='bedRoom', data=df, color='lightgreen')
plt.show()

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.333609
# std         1.830035
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False).shape
# Out:
# (45, 23)

# %% [markdown]
# - Removing all properties that has more bedrooms then 10

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='bedRoom', data=df, kde=True, stat='density',color='blue')
plt.show()

# %%
sns.boxplot(x='bedRoom', data=df, color='skyblue')
plt.show()

# %%
df['bedRoom'].describe()
# Out:
# count    3588.000000
# mean        3.203735
# std         1.393968
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ### Bathroom

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='bathroom', data=df, kde=True, stat='density',color='orange')
plt.show()

# %%
sns.boxplot(x='bathroom', data=df, color='skyblue')
plt.show()

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 3267         house  adani brahma samsara  sector 60  18.02         28200.0
# 2771         house           independent  sector 39   7.00         10000.0
# 2816         house           independent  sector 24  11.00         28902.0
#
#         area                                       areaWithType  bedRoom  \
# 3267  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 2771  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
# 2816  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 3267        12      3+       3.0  North-East  Relatively New
# 2771        11      3+       4.0  South-East  Relatively New
# 2816        11      3+       3.0        East    Old Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %% [markdown]
# ### super built up area

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='super_built_up_area', data=df, kde=True, stat='density',color='orange')
plt.show()

# %%
sns.boxplot(x='super_built_up_area', data=df, color='skyblue')
plt.show()

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
# checking outliers
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 1323          flat  bestech park view grand spa    sector 81    4.7
# 3265          flat       krrish provence estate  gwal pahari    7.5
#
#       price_per_sqft     area                             areaWithType  \
# 1323          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 3265          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1323        4         4      3+      19.0       North  Relatively New
# 3265        5         6      3+      23.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 1323               6926.0            NaN          NaN           0
# 3265              10000.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# ### built up area

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='built_up_area', data=df, kde=True, stat='density',color='orange')
plt.show()

# %%
sns.boxplot(x='built_up_area', data=df, color='skyblue')
plt.show()

# %%
# checking outliers
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 2834         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2834  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 2834  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 2834          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# 2834                1            42

# %% [markdown]
# ### carpet area

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='carpet_area', data=df, kde=True, stat='density',color='orange')
plt.show()

# %%
sns.boxplot(x='carpet_area', data=df, color='skyblue')
plt.show()

# %%
# checking outliers

df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2131          flat      godrej air  sector 85    2.5          1379.0   1812.0
# 2342          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2131  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
# 2342  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 2131  North-East  Under Construction                  NaN            NaN
# 2342       North      Moderately Old                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 2131      18122.0           1             0           0           1       1
# 2342      11000.0           0             1           0           0       0
#
#       furnishing_type  luxury_score
# ...

# %%
# Changing the value of carpet area with area, looks like there is some mistake in data
df.loc[2131,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2342          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2342  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#      facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 2342  North  Moderately Old                  NaN            NaN      11000.0
#
#       study room  servant room  store room  pooja room  others  \
# 2342           0             1           0           0       0
#
#       furnishing_type  luxury_score
# 2342                0            60

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='luxury_score', data=df, kde=True, stat='density',color='orange')
plt.show()

# %%
sns.boxplot(x='luxury_score', data=df, color='skyblue')
plt.show()

# %%
df.shape
# Out:
# (3588, 23)

# %%
# Recalculating the price_per_sqft column after applying above changes
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='price_per_sqft', data=df, kde=True, stat='density',color='orange')
plt.show()
